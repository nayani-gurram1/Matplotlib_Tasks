# %%
pip install seaborn

# %%
# Install seaborn if needed
#pip install seaborn

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set_theme(style='whitegrid')

# Load example datasets
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')

print('Datasets loaded: tips (rows={}), iris (rows={})'.format(len(tips), len(iris)))

tips.head()

sns.histplot(tips['total_bill'], kde=False)
plt.title('Histogram - Distribution of Total Bill')
plt.show()

# KDE Plot
sns.kdeplot(tips['total_bill'])
plt.title('KDE Plot - Smooth Distribution of Total Bill')
plt.show()

# Displot (Histogram + KDE)
sns.displot(tips['total_bill'], kde=True)
plt.title('Displot - Total Bill Distribution')
plt.show()

# Bar Plot - Average Tip by Gender
sns.barplot(x='sex', y='tip', data=tips)
plt.title('Bar Plot - Average Tip by Gender')
plt.show()

# Count Plot - Frequency of Days
sns.countplot(x='day', data=tips)
plt.title('Count Plot - Frequency of Days')
plt.show()

# Box Plot - Total Bill by Day
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title('Box Plot - Total Bill by Day')
plt.show()

# Violin Plot - Distribution + Summary
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Violin Plot - Total Bill by Day')
plt.show()

# Scatter Plot - Total Bill vs Tip
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex')
plt.title('Scatter Plot - Total Bill vs Tip')
plt.show()

# Line Plot - Tip vs Party Size (useful for trend-like visuals)
sns.lineplot(x='size', y='tip', data=tips)
plt.title('Line Plot - Tip vs Party Size')
plt.show()

# Relplot with Facets
sns.relplot(x='total_bill', y='tip', hue='sex', col='day', data=tips)
plt.suptitle('Relplot - Tip vs Total Bill by Day & Gender', y=1.02)
plt.show()

# Select only numeric columns
iris_num = iris.select_dtypes(include=['float', 'int'])
# Compute correlation
corr = iris_num.corr()
# Plot the heatmap
sns.heatmap(corr, annot=True,cmap='coolwarm')
plt.title("Heatmap - Correlation of Iris Features")
plt.show()

# Select only numeric columns (exclude 'species')
iris_num = iris.select_dtypes(include=['float', 'int'])
# Compute correlation matrix
corr = iris_num.corr()
# Create the clustermap
sns.clustermap(corr, cmap='coolwarm', annot=True)
plt.suptitle('Clustermap - Grouped Correlations (Numeric Only)', y=1.02)
plt.show()
# Out:
# Datasets loaded: tips (rows=244), iris (rows=150)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c727b0d-e1c0-41d8-b361-67c59bdf7cc4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c727b0d-e1c0-41d8-b361-67c59bdf7cc4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('Customer_support_data.csv')
print("First 5 rows:\n", df.head())
print("\nColumn names and data types:\n", df.dtypes)
print("\nBasic statistics:\n", df.describe())
print("\nMissing values:\n", df.isnull().sum())
# Out:
# First 5 rows:
#                                Unique id channel_name         category  \
# 0  7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1  b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2  200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3  eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4  ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
#
#                    Sub-category Customer Remarks  \
# 0                Life Insurance              NaN
# 1  Product Specific Information              NaN
# 2             Installation/demo              NaN
# 3        Reverse Pickup Enquiry              NaN
# 4                    Not Needed              NaN
#
#                                Order_id order_date_time Issue_reported at  \
# 0  c27c9bb4-fa36-4140-9f1f-21009254ffdb             NaN  01/08/2023 11:13
# 1  d406b0c7-ce17-4654-b9de-f08d421254bd             NaN  01/08/2023 12:52
# ...

# %% [markdown]
# Visualization Task (seaborn Matplotlib)
#
#
#
#  1.
#
# A. Numerical Columns (Item_price, connected_handling_time, CSAT Score)
#
# “Show me the distribution of Item_price.” → Histogram
#
# “How does CSAT Score vary overall?” → Boxplot
#
# “What is the spread of connected_handling_time values?” → Histogram + boxplot
#
# “Can I see a pie chart of CSAT scores by their value?” → Pie chart
#
# “What are the most common price ranges for items?” → Binned bar chart
#
# B. Categorical Columns (channel_name, category, Sub-category, Agent Shift, Tenure Bucket)
#
#  6. “How many tickets come from each channel_name?” → Bar chart
#
#  7. “Which category has the highest number of tickets?” → Bar chart (sorted)
#
#  8. “Show me the distribution of tickets by Agent Shift.” → Pie chart
#
#  9. “What are the top 10 Sub-category values?” → Horizontal bar chart
#
#  10. “How many tickets belong to each Tenure Bucket?” → Bar chart
#
#
#
#  2.
#
# A. Numerical vs Numerical
#
#  11. “Is there a relationship between Item_price and CSAT Score?” → Scatter plot
#
#  12. “How does connected_handling_time affect CSAT Score?” → Scatter plot + trend line
#
#  13. “Show me density or clusters of Item_price vs connected_handling_time.” → Hexbin plot
#
# B. Numerical vs Categorical
#
#  14. “What is the average CSAT Score per channel_name?” → Grouped bar chart
#
#  15. “Show distribution of Item_price per category.” → Multiple boxplots
#
#  16. “How does connected_handling_time vary by Agent Shift?” → Boxplot
#
#  17. “Show mean and variability of Item_price across top 5 Product_category.” → Error bar plot
#
#  18. “How do CSAT scores differ across Tenure Bucket?” → Bar chart
#
# C. Categorical vs Categorical
#
#  19. “Show the number of tickets by channel_name and category together.” → Stacked bar chart
#
#  20. “How does Agent Shift distribution differ across category?” → Stacked bar or grouped bar chart
#
#
#
# 3.
#
# (Using order_date_time, Issue_reported at, Survey_response_Date)
#
# “How many tickets were created per day?” → Line plot
#
# “Show daily trend of average CSAT Score.” → Line plot (rolling average optional)
#
# “Plot number of issues reported weekly.” → Bar chart (aggregated)
#
# “What is the monthly pattern of ticket volume?” → Line plot with month aggregation
#
# “How does ticket volume differ by channel_name over time?” → Multi-line plot
#
# “Show the time lag between Issue_reported at and issue_responded.” → Line or scatter plot (response time trend)
#
# “Show the volume of resolved issues over time.” → Line plot
#
# “What is the peak hour or day for incoming tickets?” → Bar chart (hourly/daily distribution)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#1
#A.
#1.
plt.figure(figsize=(8,5))
plt.hist(df['Item_price'], bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of Item Price")
plt.xlabel("Item Price ($)")
plt.ylabel("Frequency")
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#2.
plt.figure(figsize=(6,5))
plt.boxplot(df['CSAT Score'], vert=False)
plt.title("CSAT Score Distribution")
plt.xlabel("CSAT Score")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#3
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.hist(df['connected_handling_time'], bins=30, color='lightgreen', edgecolor='black')
plt.title("Histogram: Connected Handling Time")
plt.xlabel("Minutes")
plt.ylabel("Frequency")
plt.grid(axis='y')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#3.
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.hist(df['connected_handling_time'], bins=30, color='lightgreen', edgecolor='black')
plt.title("Histogram: Connected Handling Time")
plt.xlabel("Minutes")
plt.ylabel("Frequency")
plt.grid(axis='y')

plt.subplot(1,2,2)
plt.boxplot(df['connected_handling_time'], vert=False)
plt.title("Boxplot: Connected Handling Time")
plt.xlabel("Minutes")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#4.
csat_counts = df['CSAT Score'].value_counts()
plt.figure(figsize=(7,7))
plt.pie(csat_counts, labels=csat_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("CSAT Score Proportions")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#5.
bins = [0,50,100,150,200,250,300,1000]
labels = ['0-50','51-100','101-150','151-200','201-250','251-300','301+']
df['price_bin'] = pd.cut(df['Item_price'], bins=bins, labels=labels)
price_counts = df['price_bin'].value_counts().sort_index()
plt.figure(figsize=(8,5))
plt.bar(price_counts.index, price_counts.values, color='salmon')
plt.title("Item Price Ranges")
plt.xlabel("Price Range ($)")
plt.ylabel("Number of Items")
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#B.
#6.
channel_counts = df['channel_name'].value_counts()
plt.figure(figsize=(8,5))
plt.bar(channel_counts.index, channel_counts.values, color='lightblue')
plt.title("Tickets by Channel")
plt.xlabel("Channel")
plt.ylabel("Number of Tickets")
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#7
category_counts = df['category'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(10,5))
plt.bar(category_counts.index, category_counts.values, color='orange')
plt.title("Tickets by Category")
plt.xlabel("Category")
plt.ylabel("Number of Tickets")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#8
shift_counts = df['Agent Shift'].value_counts()
plt.figure(figsize=(7,7))
plt.pie(shift_counts, labels=shift_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Tickets by Agent Shift")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#9
subcat_counts = df['Sub-category'].value_counts().head(10)
plt.figure(figsize=(10,5))
plt.barh(subcat_counts.index[::-1], subcat_counts.values[::-1], color='green')
plt.title("Top 10 Sub-category Tickets")
plt.xlabel("Number of Tickets")
plt.ylabel("Sub-category")
plt.grid(axis='x')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#10
tenure_counts = df['Tenure Bucket'].value_counts()
plt.figure(figsize=(8,5))
plt.bar(tenure_counts.index, tenure_counts.values, color='purple')
plt.title("Tickets by Agent Tenure")
plt.xlabel("Tenure Bucket")
plt.ylabel("Number of Tickets")
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#2
#A
#11
plt.figure(figsize=(8,5))
plt.scatter(df['Item_price'], df['CSAT Score'], alpha=0.5, color='red')
plt.title("Item Price vs CSAT Score")
plt.xlabel("Item Price ($)")
plt.ylabel("CSAT Score")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#12
plt.figure(figsize=(8,5))
sns.regplot(x='connected_handling_time', y='CSAT Score', data=df, scatter_kws={'alpha':0.3}, line_kws={'color':'blue'})
plt.title("Handling Time vs CSAT Score")
plt.xlabel("Connected Handling Time (min)")
plt.ylabel("CSAT Score")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#13
plt.figure(figsize=(8,6))
plt.hexbin(df['Item_price'], df['connected_handling_time'], gridsize=40, cmap='Blues', mincnt=1)
plt.colorbar(label='Counts')
plt.title("Item Price vs Handling Time Density")
plt.xlabel("Item Price ($)")
plt.ylabel("Connected Handling Time (min)")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#B
#14
avg_csat_channel = df.groupby('channel_name')['CSAT Score'].mean()
plt.figure(figsize=(8,5))
plt.bar(avg_csat_channel.index, avg_csat_channel.values, color='orange')
plt.title("Average CSAT by Channel")
plt.xlabel("Channel")
plt.ylabel("Average CSAT Score")
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#15
plt.figure(figsize=(10,6))
sns.boxplot(x='category', y='Item_price', data=df)
plt.title("Item Price Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Item Price ($)")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#16
plt.figure(figsize=(8,5))
sns.boxplot(x='Agent Shift', y='connected_handling_time', data=df)
plt.title("Handling Time by Agent Shift")
plt.xlabel("Agent Shift")
plt.ylabel("Connected Handling Time (min)")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#17
top5_products = df['Product_category'].value_counts().head(5).index
means = df[df['Product_category'].isin(top5_products)].groupby('Product_category')['Item_price'].mean()
stds = df[df['Product_category'].isin(top5_products)].groupby('Product_category')['Item_price'].std()
plt.figure(figsize=(8,5))
plt.errorbar(means.index, means.values, yerr=stds.values, fmt='o', capsize=5, color='blue')
plt.title("Mean & Variability of Item Price (Top 5 Products)")
plt.xlabel("Product Category")
plt.ylabel("Item Price ($)")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#18
avg_csat_tenure = df.groupby('Tenure Bucket')['CSAT Score'].mean()
plt.figure(figsize=(8,5))
plt.bar(avg_csat_tenure.index, avg_csat_tenure.values, color='purple')
plt.title("Average CSAT by Tenure Bucket")
plt.xlabel("Tenure Bucket")
plt.ylabel("Average CSAT Score")
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#C
#19
channel_category = df.groupby(['channel_name','category']).size().unstack()
channel_category.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title("Tickets by Channel and Category")
plt.xlabel("Channel")
plt.ylabel("Number of Tickets")
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
sns.set(style="whitegrid")
#20
shift_category = df.groupby(['category','Agent Shift']).size().unstack()
shift_category.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title("Agent Shift Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Number of Tickets")
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
df['Issue_reported at'] = pd.to_datetime(df['Issue_reported at'], dayfirst=True, errors='coerce')
sns.set(style="whitegrid")
daily_tickets = df.groupby(df['Issue_reported at'].dt.date).size()
#3
#21
plt.figure(figsize=(12,5))
plt.plot(daily_tickets.index, daily_tickets.values, color='blue', marker='o', linewidth=2)
plt.title("Tickets Created per Day", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Tickets", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
df['Survey_response_Date'] = pd.to_datetime(df['Survey_response_Date'], dayfirst=True, errors='coerce')
sns.set(style="whitegrid")
#22
daily_csat = df.groupby(df['Survey_response_Date'].dt.date)['CSAT Score'].mean()
plt.figure(figsize=(12,5))
plt.plot(daily_csat.index, daily_csat.values, color='green', marker='o', linewidth=2)
plt.title("Daily Average CSAT Score", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Average CSAT Score", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1782256781.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Survey_response_Date'] = pd.to_datetime(df['Survey_response_Date'], dayfirst=True, errors='coerce')

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e91908d8-d259-412b-a05d-8e4555ff26ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e91908d8-d259-412b-a05d-8e4555ff26ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
df['Issue_reported at'] = pd.to_datetime(df['Issue_reported at'], errors='coerce', dayfirst=True)
sns.set(style="whitegrid")
#23
weekly_tickets = df.groupby(df['Issue_reported at'].dt.isocalendar().week).size()
plt.figure(figsize=(10,5))
plt.bar(weekly_tickets.index, weekly_tickets.values, color='orange')
plt.title("Weekly Tickets", fontsize=14)
plt.xlabel("Week Number", fontsize=12)
plt.ylabel("Number of Tickets", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
df['Issue_reported at'] = pd.to_datetime(df['Issue_reported at'], dayfirst=True, errors='coerce')
sns.set(style="whitegrid")
#24
monthly_tickets = df.groupby(df['Issue_reported at'].dt.month).size()
plt.figure(figsize=(10,5))
plt.plot(monthly_tickets.index, monthly_tickets.values, marker='o', linestyle='-', color='purple')
plt.title("Monthly Ticket Volume", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Number of Tickets", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(range(1,13))
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
df['Issue_reported at'] = pd.to_datetime(df['Issue_reported at'], dayfirst=True, errors='coerce')
sns.set(style="whitegrid")
#25
channels = df['channel_name'].unique()
plt.figure(figsize=(12,6))
for ch in channels:
    temp = df[df['channel_name'] == ch].groupby(df['Issue_reported at'].dt.date).size()
    plt.plot(temp.index, temp.values, label=ch)
plt.title("Ticket Volume by Channel Over Time", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Tickets", fontsize=12)
plt.legend(title="Channel")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
df['Issue_reported at'] = pd.to_datetime(df['Issue_reported at'], dayfirst=True, errors='coerce')
df['issue_responded'] = pd.to_datetime(df['issue_responded'], dayfirst=True, errors='coerce')
sns.set(style="whitegrid")
#26
df['response_time'] = (df['issue_responded'] - df['Issue_reported at']).dt.total_seconds() / 60
df = df.dropna(subset=['response_time'])
plt.figure(figsize=(12,5))
plt.plot(df['Issue_reported at'], df['response_time'], 'o', markersize=2, alpha=0.3, color='purple')
plt.title("Response Time Trend", fontsize=14)
plt.xlabel("Issue Reported Date", fontsize=12)
plt.ylabel("Response Time (minutes)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
df['Issue_reported at'] = pd.to_datetime(df['Issue_reported at'], dayfirst=True, errors='coerce')
df['issue_responded'] = pd.to_datetime(df['issue_responded'], dayfirst=True, errors='coerce')
#27
resolved_df = df.dropna(subset=['issue_responded'])
print(resolved_df['issue_responded'].dtype)
resolved_daily = resolved_df.groupby(resolved_df['issue_responded'].dt.date).size()
sns.set(style="whitegrid")
plt.figure(figsize=(12,6))
plt.plot(resolved_daily.index, resolved_daily.values, marker='o', color='teal', linewidth=2)
plt.title("Volume of Resolved Issues Over Time", fontsize=14)
plt.xlabel("Date (Issue Responded)", fontsize=12)
plt.ylabel("Number of Resolved Issues", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# datetime64[ns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('Customer_support_data.csv')
df['Issue_reported at'] = pd.to_datetime(df['Issue_reported at'], dayfirst=True, errors='coerce')
df = df.dropna(subset=['Issue_reported at'])
sns.set(style="whitegrid")
#28
df['hour'] = df['Issue_reported at'].dt.hour
hourly_counts = df['hour'].value_counts().sort_index()
plt.figure(figsize=(10,5))
plt.bar(hourly_counts.index, hourly_counts.values, color='cyan', edgecolor='black')
plt.title("Tickets by Hour of Day", fontsize=14)
plt.xlabel("Hour of Day", fontsize=12)
plt.ylabel("Number of Tickets", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(range(0,24))
plt.tight_layout()
plt.show()
